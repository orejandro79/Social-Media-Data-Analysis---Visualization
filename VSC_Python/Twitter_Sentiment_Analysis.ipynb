# %% [markdown]
# # SOCIAL MEDIA ANALYSIS: Twitter Sentiment Analysis
# ## 1. Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## 2. Read Twitter Sentiment Analysis Dataset

# %%
df = pd.read_csv("C:/Users/Usuario/Documents/GitHub/Social-Media-Data-Analysis---Visualization/VSC_Python/twitter.csv")
df
# Out:
#           id  label                                              tweet
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 2          3      0                                bihday your majesty
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# ...      ...    ...                                                ...
# 31957  31958      0  ate @user isz that youuu?ðððððð...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31959  31960      0  listening to sad songs on a monday morning otw...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962      0                   thank you @user for you follow
#
# [31962 rows x 3 columns]

# %% [markdown]
# ## 3. Import another neccesary libraries

# %%
pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         2.4.1
# certifi           2024.7.4
# click             8.1.7
# colorama          0.4.6
# comm              0.2.2
# contourpy         1.2.1
# cycler            0.12.1
# debugpy           1.8.2
# decorator         5.1.1
# executing         2.0.1
# fonttools         4.53.1
# geopandas         1.0.1
# ipykernel         6.29.5
# ipython           8.26.0
# jedi              0.19.1
# joblib            1.4.2
# jupyter_client    8.6.2
# jupyter_core      5.7.2
# kiwisolver        1.4.5
# matplotlib        3.9.1
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# nltk              3.9.1
# numpy             2.0.0
# packaging         24.1
# pandas            2.2.2
# parso             0.8.4
# pillow            10.4.0
# pip               24.1.2
# platformdirs      4.2.2
# prompt_toolkit    3.0.47
# psutil            6.0.0
# pure-eval         0.2.2
# Pygments          2.18.0
# pymssql           2.3.0
# ...

# %%
pip install wordcloud
# Out:
# ...
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip show wordcloud
# Out:
# Name: wordcloud
# Version: 1.9.4
# Summary: A little word cloud generator
# Home-page: https://github.com/amueller/word_cloud
# Author:
# Author-email: Andreas Mueller <t3kcit+wordcloud@gmail.com>
# License: MIT License
# Location: c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: matplotlib, numpy, pillow
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip show nltk
# Out:
# Name: nltk
# Version: 3.9.1
# Summary: Natural Language Toolkit
# Home-page: https://www.nltk.org/
# Author: NLTK Team
# Author-email: nltk.team@gmail.com
# License: Apache License, Version 2.0
# Location: c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: click, joblib, regex, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.2

# %%
# Imports the WordCloud class, which is used to generate word clouds, graphic visualizations where the most frequent words appear larger
from wordcloud import WordCloud
# Imports a set of "stopwords" (stopwords) from the NLTK library, which are common words in a language (such as "and", "the", "a") that are usually ignored in text analysis.
from nltk.corpus import stopwords
# Imports the word_tokenize function, which is used to split text into individual words (tokenization).
from nltk.tokenize import word_tokenize
# Imports the SentimentIntensityAnalyzer class, which is used to perform sentiment analysis, evaluating the polarity (positive, negative or neutral) of a text.
from nltk.sentiment import SentimentIntensityAnalyzer
#  is used to convert a collection of text documents into a feature count array (essentially counting how many times each word appears in the text).
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
# which allows you to generate a report that shows performance metrics (such as precision, recall, and F1 score) for a classification model.
from sklearn.metrics import classification_report

# %% [markdown]
# ## 4. Explore the Dataset

# %%
# Check basic information
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31962 entries, 0 to 31961
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      31962 non-null  int64
#  1   label   31962 non-null  int64
#  2   tweet   31962 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 749.2+ KB
#                  id         label
# count  31962.000000  31962.000000
# mean   15981.500000      0.070146
# std     9226.778988      0.255397
# min        1.000000      0.000000
# 25%     7991.250000      0.000000
# 50%    15981.500000      0.000000
# 75%    23971.750000      0.000000
# max    31962.000000      1.000000

# %%
df.head(30)
# Out:
#     id  label                                              tweet
# 0    1      0   @user when a father is dysfunctional and is s...
# 1    2      0  @user @user thanks for #lyft credit i can't us...
# 2    3      0                                bihday your majesty
# 3    4      0  #model   i love u take with u all the time in ...
# 4    5      0             factsguide: society now    #motivation
# 5    6      0  [2/2] huge fan fare and big talking before the...
# 6    7      0   @user camping tomorrow @user @user @user @use...
# 7    8      0  the next school year is the year for exams.ð...
# 8    9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9   10      0   @user @user welcome here !  i'm   it's so #gr...
# 10  11      0   â #ireland consumer price index (mom) climb...
# 11  12      0  we are so selfish. #orlando #standwithorlando ...
# 12  13      0  i get to see my daddy today!!   #80days #getti...
# ...

# %%
# Identify missing values
print(df.isnull().sum())
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %% [markdown]
# ## 5. Data Cleaning

# %%
# Handle missing values
df.dropna(subset=['tweet'], inplace=True)
df.head(30)
# Out:
#     id  label                                              tweet
# 0    1      0   @user when a father is dysfunctional and is s...
# 1    2      0  @user @user thanks for #lyft credit i can't us...
# 2    3      0                                bihday your majesty
# 3    4      0  #model   i love u take with u all the time in ...
# 4    5      0             factsguide: society now    #motivation
# 5    6      0  [2/2] huge fan fare and big talking before the...
# 6    7      0   @user camping tomorrow @user @user @user @use...
# 7    8      0  the next school year is the year for exams.ð...
# 8    9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9   10      0   @user @user welcome here !  i'm   it's so #gr...
# 10  11      0   â #ireland consumer price index (mom) climb...
# 11  12      0  we are so selfish. #orlando #standwithorlando ...
# 12  13      0  i get to see my daddy today!!   #80days #getti...
# ...
